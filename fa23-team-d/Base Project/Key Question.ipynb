# %%
from IPython.display import display, Image
display(Image(filename='fy4.jpg'))

# %% [markdown]
# 1. How the city of Boston spends its annual budget

# %% [markdown]
# **FY21 Adopted Revenue Budget**:
#
# Assessing: 79.1%
#
# Treasury: 15.9%
#
# Auditing, Inspectional Services, Transportation: 5% (combined)
#
# **FY22 Adopted Revenue Budget**:
#
# Assessing: 77.2%
#
# Treasury: 17.5%
#
# Auditing, Inspectional Services, Transportation: 5.3% (combined)
#
# **FY23 Adopted Revenue Budget**:
#
# Assessing: 78.0%
#
# Treasury: 16.2%
#
# Auditing, Inspectional Services, Transportation: 5.8% (combined)
#
# **FY24 Adopted Revenue Budget**:
#
# Assessing: 76.4%
#
# Treasury: 18.5%
#
# Auditing, Inspectional Services, Transportation: 5.1% (combined)
#
# From these charts, it's evident that a majority of Boston's revenue budget consistently goes towards "Assessing", followed by "Treasury". The combined percentage for "Auditing", "Inspectional Services", and "Transportation" remains relatively small across the four fiscal years.

# %% [markdown]
# 2. How this has changed over time

# %% [markdown]
# Here’s a brief summary of how the distribution has changed over time:
#
# **Assessing**:
#
# FY21: 79.1%, FY22: 77.2%, FY23: 78.0%, FY24: 76.4%
#
# The budget for “Assessing” has seen a slight decrease over the years, starting at 79.1% in FY21 and dropping to 76.4% by FY24.
#
# **Treasury**:
#
# FY21: 15.9%, FY22: 17.5%, FY23: 16.2%, FY24: 18.5%
#
# The allocation for “Treasury” has shown fluctuations. It increased from FY21 to FY22, slightly decreased in FY23, and again saw an increase in FY24.
#
# **Transportation, Inspectional Services, and Auditing**:
#
# These three sectors combined occupy a smaller percentage of the budget. However, their exact distributions are hard to distinguish from the charts due to their close proximity in size. What can be observed is that their combined allocation has remained relatively consistent over the four years.
#
# In summary, the most notable change is seen in the “Assessing” and “Treasury” sectors. The “Assessing” budget allocation has shown a mild decrease over the four years, while the “Treasury” allocation has fluctuated but ended with a net increase by FY24. The combined allocation for “Transportation,” “Inspectional Services,” and “Auditing” seems to have remained relatively stable.

# %% [markdown]
# 3. how the projected spending has differed from the actual spending
