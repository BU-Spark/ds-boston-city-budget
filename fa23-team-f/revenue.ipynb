# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
# philly_data = pd.read_csv("/content/drive/My Drive/DS/proj/PhillyRevenue.csv")
# boston_data = pd.read_csv("/content/drive/My Drive/DS/proj/fy24-adopted-revenue-budget.csv")

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Philly: Grouping by name and summing the latest available year's revenue
philly_grouped = philly_data.groupby('name')['2025 (Revised)'].sum()
philly_grouped.plot(kind='pie', autopct='%1.1f%%', figsize=(10, 10))
plt.title('Philadelphia Revenue Distribution (2025 Revised)')
plt.ylabel('')
plt.show()

# Boston Data: Grouping by 'Revenue Category' and summing the latest available year's revenue
# Adjust the year column to the latest available in your dataset
#error

#Removing commas, dollar signs, and converting the column to numeric data type
boston_data['FY24 Adopted'] = boston_data['FY24 Adopted'].replace('[\$,]', '', regex=True).astype(float)

boston_grouped = boston_data.groupby('Revenue Category')['FY24 Adopted'].sum()
boston_grouped.plot(kind='pie', autopct='%1.1f%%', figsize=(10, 10))
plt.title('Boston Revenue Distribution (FY24 Adopted)')
plt.ylabel('')
plt.show()

# %% [markdown]
# The visualizations you've provided offer a clear comparison of the revenue distributions for Philadelphia and Boston.
#
# Philadelphia: The largest revenue source is the Wage and Earnings Tax, which makes up a significant portion of the revenue at 33.3%. Business Income & Receipts Tax and Real Estate Tax are also significant contributors.
#
# Boston: The Property Tax Levy is the dominant source of revenue at 72.4%, which is quite substantial compared to Philadelphia's distribution. State Aid and Excises form the next significant sources, but they are much smaller in proportion than the Property Tax Levy.
#
# From this comparison, we can draw several conclusions:
#
# Diversification of Revenue: Philadelphia has a more diversified revenue portfolio compared to Boston, which relies heavily on property taxes. Boston may benefit from exploring alternative revenue sources to reduce over-reliance on property taxes and mitigate risks associated with property value fluctuations.
#
# Taxation Focus: The heavy reliance on Wage and Earnings Tax in Philadelphia suggests a focus on income-based revenue. In contrast, Boston's reliance on property taxes may indicate a different approach to taxation that could be influenced by property values and the real estate market's stability.
#
# Improvement Recommendations for Boston:
#
# Assess the potential for increasing or adding taxes similar to Philadelphia’s Wage and Earnings Tax if currently feasible and socially acceptable.
# Consider whether there are untapped revenue sources that could be developed to balance the revenue streams.
# Evaluate the current property tax structure to ensure it remains competitive and does not overburden property owners, especially if property values fluctuate significantly.
# It's important to note that any changes to tax policy should be considered carefully, with an understanding of the economic environment, the tax base, and the potential impacts on residents and businesses.

# %%
boston_data['FY24 Adopted'] = boston_data['FY24 Adopted'].replace('[\$,]', '', regex=True).astype(float)

# Sum the revenue for the latest available year for Philadelphia
philly_total = philly_data['2025 (Revised)'].sum()
philly_revenues = philly_data.groupby('name')['2025 (Revised)'].sum() / philly_total * 100

# Sum the revenue for the latest available year for Boston
boston_total = boston_data['FY24 Adopted'].sum()
boston_revenues = boston_data.groupby('Revenue Category')['FY24 Adopted'].sum() / boston_total * 100

# Create subplots
fig, axs = plt.subplots(1, 2, figsize=(14, 7))

# Plot Philadelphia data
axs[0].pie(philly_revenues, labels=philly_revenues.index, autopct='%1.1f%%', startangle=140)
axs[0].set_title('Philadelphia Revenue Distribution (2025 Revised)')

# Plot Boston data
axs[1].pie(boston_revenues, labels=boston_revenues.index, autopct='%1.1f%%', startangle=140)
axs[1].set_title('Boston Revenue Distribution (FY24 Adopted)')

plt.tight_layout()
plt.show()

# %% [markdown]
# Differences:
#
# Philadelphia has a more diversified revenue stream with the largest source being the Wage and Earnings Tax at 33.3%, whereas Boston relies heavily on Property Tax Levy, which constitutes 72.4% of its revenue.
# Philadelphia has a significant portion of its revenue coming from Business Income & Receipts Tax and Real Estate Tax (each constituting 14.5%), which do not appear to be as significant in Boston's distribution.
# Similarities:
#
# Both cities receive a portion of their revenue from State Aid, though the proportion is much larger in Boston.
# Each city has categorized a segment of revenue as 'Other', which suggests miscellaneous sources of income.
# These insights indicate that while both cities rely on taxes as primary sources of revenue, the types and diversifications of the taxes differ, with Boston depending more on property taxes and Philadelphia having a broader mix including wage taxes and business taxes.

# %% [markdown]
# Differences:
#
# Diversification: Philadelphia's revenue streams are more diversified, with the largest category (Wage and Earnings) at 33.3%, whereas Boston's revenue is heavily concentrated in the Property Tax Levy at 72.4%.
# Tax Categories: Philadelphia has several significant tax categories like Business Income & Receipts Tax and Real Estate Tax, each accounting for a substantial portion of the revenue. In contrast, Boston's second-largest category, State Aid, is much smaller than its Property Tax Levy.
# Similarities:
#
# State Aid: Both cities receive a noticeable portion of their revenue from State Aid, though it's a much larger share in Boston.
# Other Revenues: Each city has a segment of 'Other' revenues, indicating a variety of smaller or miscellaneous sources of income.
# These visual comparisons highlight the need for Boston to potentially diversify its revenue sources to mitigate risks associated with heavy reliance on property taxes, especially in economic downturns that could affect property values.

# %%
philadelphia_spending = pd.read_csv("/content/drive/My Drive/DS/proj/PhillySpending.csv")
boston_capital = pd.read_csv("/content/drive/My Drive/DS/proj/fy24-capital-budget-plan-recommended.csv")
boston_operating = pd.read_csv("/content/drive/My Drive/DS/proj/8f2971f0-7a0d-401d-8376-0289e3b810ba.csv")

# %%
boston_capital_total = boston_capital['Total_Project_Budget'].sum()
boston_operating_total = boston_operating[['FY21 Actual Expense', 'FY22 Actual Expense', 'FY23 Appropriation', 'FY24 Recommended']].sum().sum()
philadelphia_total = philadelphia_spending[['2020 (Proposed)', '2021 (Proposed)', '2022 (Proposed)', '2023 (Proposed)', '2024 (Proposed)', '2025 (Proposed)']].sum().sum()
# Convert budget columns to numeric format, if not already
boston_capital['Total_Project_Budget'] = pd.to_numeric(boston_capital['Total_Project_Budget'], errors='coerce')
boston_operating[['FY21 Actual Expense', 'FY22 Actual Expense', 'FY23 Appropriation', 'FY24 Recommended']] = boston_operating[['FY21 Actual Expense', 'FY22 Actual Expense', 'FY23 Appropriation', 'FY24 Recommended']].apply(pd.to_numeric, errors='coerce')
philadelphia_spending[['2020 (Proposed)', '2021 (Proposed)', '2022 (Proposed)', '2023 (Proposed)', '2024 (Proposed)', '2025 (Proposed)']] = philadelphia_spending[['2020 (Proposed)', '2021 (Proposed)', '2022 (Proposed)', '2023 (Proposed)', '2024 (Proposed)', '2025 (Proposed)']].apply(pd.to_numeric, errors='coerce')

# Fill NaN values with zeros
boston_capital.fillna(0, inplace=True)
boston_operating.fillna(0, inplace=True)
philadelphia_spending.fillna(0, inplace=True)

# Recalculate the totals
boston_capital_total = boston_capital['Total_Project_Budget'].sum()
boston_operating_total = boston_operating[['FY21 Actual Expense', 'FY22 Actual Expense', 'FY23 Appropriation', 'FY24 Recommended']].sum().sum()
philadelphia_total = philadelphia_spending[['2020 (Proposed)', '2021 (Proposed)', '2022 (Proposed)', '2023 (Proposed)', '2024 (Proposed)', '2025 (Proposed)']].sum().sum()

# Display the total budget summaries
print("Total Budget for Boston Capital Projects:", boston_capital_total)
print("Total Budget for Boston Operating Expenses:", boston_operating_total)
print("Total Budget for Philadelphia Spending:", philadelphia_total)
# Out:
# Total Budget for Boston Capital Projects: 4021421610.0
# Total Budget for Boston Operating Expenses: 12520459658.11024
# Total Budget for Philadelphia Spending: 32489306344

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming the previous code has been executed and the totals have been calculated
data = {
    'City': ['Boston', 'Boston', 'Philadelphia'],
    'Budget Type': ['Capital', 'Operating', 'Spending'],
    'Total Budget': [boston_capital_total, boston_operating_total, philadelphia_total]
}

df = pd.DataFrame(data)

# Create a bar chart
plt.figure(figsize=(10, 6))
bar_plot = plt.bar(df['Budget Type'], df['Total Budget'], color=['blue', 'green', 'red'])

# Adding labels and title
plt.xlabel('Budget Type')
plt.ylabel('Total Budget')
plt.title('Budget Comparison between Boston and Philadelphia')
plt.xticks(rotation=45)
plt.grid(axis='y')

# Adding the budget values on top of the bars
for bar in bar_plot:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), va='bottom', ha='center')

# Show plot
plt.show()

# %%
boston_yearly = boston_operating[['FY21 Actual Expense', 'FY22 Actual Expense']].sum()

# Philadelphia's yearly budget
# Summing up for two years as an example (you should replace these with correct column names)
philadelphia_yearly = philadelphia_spending[['2020 (Proposed)', '2021 (Proposed)']].sum()

# Plotting
plt.figure(figsize=(10, 6))

# Plot for Boston
plt.plot(['FY21', 'FY22'], boston_yearly, label='Boston', marker='o')

# Plot for Philadelphia
plt.plot(['2020', '2021'], philadelphia_yearly, label='Philadelphia', marker='o')

plt.title('Yearly Budget Trend for Boston and Philadelphia (Simplified Example)')
plt.xlabel('Year')
plt.ylabel('Total Budget')
plt.legend()
plt.grid(True)
plt.show()

# %%
philadelphia_spending = pd.read_csv("/content/drive/My Drive/DS/proj/PhillySpending.csv")
philly_rev = pd.read_csv("/content/drive/My Drive/DS/proj/PhillyRevenue.csv")
boston_capital = pd.read_csv("/content/drive/My Drive/DS/proj/fy24-capital-budget-plan-recommended.csv")
boston_operating = pd.read_csv("/content/drive/My Drive/DS/proj/8f2971f0-7a0d-401d-8376-0289e3b810ba.csv")
boston_revenue = pd.read_csv("/content/drive/My Drive/DS/proj/fy24-adopted-revenue-budget.csv")

# %%
philly_dept_spending = philadelphia_spending.groupby('dept_name').sum()

# Assuming Boston's operating and capital budgets should be combined for department-wise comparison
# Concatenating Boston's capital and operating budgets
boston_budget = pd.concat([boston_capital, boston_operating])

# Aggregate Boston spending by department
boston_dept_spending = boston_budget.groupby('Department').sum()

# For simplicity, let's just focus on total spending
# You can add more specific columns based on your datasets
philly_dept_total = philly_dept_spending.sum(axis=1)  # Sum across columns for each department
boston_dept_total = boston_dept_spending.sum(axis=1)  # Sum across columns for each department

# Creating a comparison DataFrame
comparison = pd.DataFrame({
    'Philadelphia Spending': philly_dept_total,
    'Boston Spending': boston_dept_total
})

# Sorting by one of the cities for better visualization
comparison.sort_values(by='Philadelphia Spending', ascending=False, inplace=True)

# Display the comparison
print(comparison)

# Optional: Plotting for visual comparison (if you have matplotlib installed)
import matplotlib.pyplot as plt
comparison.plot(kind='bar', figsize=(10, 6))
plt.title('Department-wise Spending Comparison: Boston vs Philadelphia')
plt.ylabel('Total Spending')
plt.xlabel('Department')
plt.show()
# Out:
# <ipython-input-12-795d4ac8053c>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   philly_dept_spending = philadelphia_spending.groupby('dept_name').sum()
# <ipython-input-12-795d4ac8053c>:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   boston_dept_spending = boston_budget.groupby('Department').sum()
#                                 Philadelphia Spending  Boston Spending
# Finance                                  2.378761e+10              NaN
# Police                                   9.043242e+09              NaN
# Debt Service                             3.951856e+09              NaN
# ...

# %%
# For Philadelphia Spending Budget
print("Unique departments in Philadelphia Spending Budget:")
print(philadelphia_spending['dept_name'].unique())

print("\nUnique major class descriptions in Philadelphia Spending Budget:")
print(philadelphia_spending['major_class_description'].unique())

# For Boston Capital Budget
print("\nUnique departments in Boston Capital Budget:")
print(boston_capital['Department'].unique())

# For Boston Operating Budget
print("\nUnique departments in Boston Operating Budget:")
print(boston_operating['Dept'].unique())
# Out:
# Unique departments in Philadelphia Spending Budget:
# ['City Council' 'Labor' 'Innovation and Technology' 'Mayor'
#  'Community Empowerment' 'Managing Director' 'Police' 'Streets' 'Fire'
#  'Public Health' 'Behavioral Health' 'Parks & Rec' 'Atwater Kent'
#  'Public Property' 'Human Services' 'Prisons' 'Homeless Services' 'Fleet'
#  'Licenses & Inspections' 'Board of Review' 'Board of Bldg. Stds.'
#  'Records' 'Art Museum' 'Finance' 'Revenue' 'Debt Service' 'Procurement'
#  'City Treasurer' 'City Rep' 'Commerce' 'Law' 'Board of Ethics'
#  'Inspector General' 'Sustainability' 'Mural Arts' 'Free Library'
#  'Human Relations ' 'Civil Service Commission' 'Human Resources'
#  'Arts & Culture' 'Property Assessment' 'City Controller'
#  'Revision of Taxes' 'Chief Admin. Officer' 'Children and Families'
#  'Register of Wills' 'District Attorney' 'Sheriff'
#  'Planning & Development' 'City Commissioners' 'First Judicial District']
#
# ...

# %%
philly_mappings = {
    'City Council': 'General Government & Administration',
    'Labor': 'General Government & Administration',
    'Innovation and Technology': 'Education',
    'Mayor': 'General Government & Administration',
    'Community Empowerment': 'Community & Economic Development',
    'Managing Director': 'General Government & Administration',
    'Police': 'Public Safety',
    'Streets': 'Infrastructure & Public Works',
    'Fire': 'Public Safety',
    'Public Health': 'Health & Human Services',
    'Behavioral Health': 'Health & Human Services',
    'Parks & Rec': 'Culture & Recreation',
    'Atwater Kent': 'Culture & Recreation',
    'Public Property': 'Infrastructure & Public Works',
    'Human Services': 'Health & Human Services',
    'Prisons': 'Public Safety',
    'Homeless Services': 'Health & Human Services',
    'Fleet': 'Infrastructure & Public Works',
    'Licenses & Inspections': 'Infrastructure & Public Works',
    'Board of Review': 'General Government & Administration',
    'Board of Bldg. Stds.': 'General Government & Administration',
    'Records': 'General Government & Administration',
    'Art Museum': 'Culture & Recreation',
    'Finance': 'General Government & Administration',
    'Revenue': 'General Government & Administration',
    'Debt Service': 'General Government & Administration',
    'Procurement': 'General Government & Administration',
    'City Treasurer': 'General Government & Administration',
    'City Rep': 'General Government & Administration',
    'Commerce': 'Community & Economic Development',
    'Law': 'General Government & Administration',
    'Board of Ethics': 'General Government & Administration',
    'Inspector General': 'General Government & Administration',
    'Sustainability': 'General Government & Administration',
    'Mural Arts': 'Culture & Recreation',
    'Free Library': 'Education',
    'Human Relations ': 'General Government & Administration',
    'Civil Service Commission': 'General Government & Administration',
    'Human Resources': 'General Government & Administration',
    'Arts & Culture': 'Culture & Recreation',
    'Property Assessment': 'General Government & Administration',
    'City Controller': 'General Government & Administration',
    'Revision of Taxes': 'General Government & Administration',
    'Chief Admin. Officer': 'General Government & Administration',
    'Children and Families': 'Health & Human Services',
    'Register of Wills': 'General Government & Administration',
    'District Attorney': 'Public Safety',
    'Sheriff': 'Public Safety',
    'Planning & Development': 'Community & Economic Development',
    'City Commissioners': 'General Government & Administration',
    'First Judicial District': 'Public Safety'
}

# Define the mapping for Boston departments to broader categories

# %%
boston_category_mapping = {
    'Boston Centers for Youth and Families': 'Health & Human Services',
    'Boston Planning and Development Agency': 'Community & Economic Development',
    'Boston Public Library': 'Culture & Recreation',
    'Boston Public Schools': 'Education',
    'Department of Innovation and Technology': 'General Government & Administration',
    'Emergency Management': 'Public Safety',
    'Environment Department': 'Infrastructure & Public Works',
    'Fire Department': 'Public Safety',
    "Mayor's Office of Housing": 'Community & Economic Development',
    'Office of Arts & Culture': 'Culture & Recreation',
    'Office of New Urban Mechanics': 'General Government & Administration',
    'Parks and Recreation Department': 'Infrastructure & Public Works',
    'Police Department': 'Public Safety',
    'Property Management Department': 'Infrastructure & Public Works',
    'Public Health Commission': 'Health & Human Services',
    'Public Works Department': 'Infrastructure & Public Works',
    'Transportation Department': 'Infrastructure & Public Works',
    #more mappings for operating budget departments
    "Mayor's Office": 'General Government & Administration',
    'Election Department': 'General Government & Administration',
    'Intergovernmental Relations': 'General Government & Administration',
    'Law Department': 'General Government & Administration',
    'Office of Equity': 'General Government & Administration',
    'Office of Diversity': 'General Government & Administration',
    'Office of Resiliency & Racial Equity': 'General Government & Administration',
    'Office of Language & Communications Access': 'General Government & Administration',
    'Human Right Commission': 'General Government & Administration',
    'Office for Immigrant Advancement': 'General Government & Administration',
    "Women's Advancement": 'General Government & Administration',
    'Black Male Advancement': 'General Government & Administration',
    'Fair Housing & Equity': 'General Government & Administration',
    'LGBTQ+ Advancement': 'General Government & Administration',
    'Commission for Persons with Disabilities': 'General Government & Administration',
    'Office of Police Accountability & Transparency': 'Public Safety',
    'Inspectional Services Department': 'Infrastructure & Public Works',
    'Neighborhood Services': 'Community & Economic Development',
    'Consumer Affairs & Licensing': 'General Government & Administration',
    'Supplier Diversity': 'General Government & Administration',
    'Office of Tourism': 'Culture & Recreation',
    'Labor Compliance and Worker Protection': 'General Government & Administration',
    'Youth Employment and Opportunity': 'Health & Human Services',
    'Office of Historic Preservation': 'Culture & Recreation',
    'Office of Food Justice': 'Health & Human Services',
    'Office of Finance': 'General Government & Administration',
    'Assessing Department': 'General Government & Administration',
    'Auditing Department': 'General Government & Administration',
    'Budget Management': 'General Government & Administration',
    'Office of Participatory Budgeting': 'General Government & Administration',
    'Execution of Courts': 'Public Safety',
    'Pensions & Annuities - City': 'General Government & Administration',
    'Procurement': 'General Government & Administration',
    'Treasury Department': 'General Government & Administration',
    'Office of People Operations': 'General Government & Administration',
    'Health Insurance': 'Health & Human Services',
    'Human Resources': 'General Government & Administration',
    'Medicare': 'Health & Human Services',
    'Office of Labor Relations': 'General Government & Administration',
    'Registry Division': 'General Government & Administration',
    'Unemployment Compensation': 'General Government & Administration',
    "Workers' Compensation Fund": 'General Government & Administration',
    'Office of Human Services': 'Health & Human Services',
    'Age Strong': 'Health & Human Services',
    'Library Department': 'Culture & Recreation',
    'Boston VETS': 'Health & Human Services',
    'Central Fleet Management': 'Infrastructure & Public Works',
    'Office of Streets': 'Infrastructure & Public Works',
    'Snow & Winter Management': 'CInfrastructure & Public Works',
    'Transportation Department': 'Infrastructure & Public Works',
    'Planning & Design': 'Community & Economic Development',
    'City Clerk': 'General Government & Administration',
    'City Council': 'General Government & Administration',
    'Finance Commission': 'General Government & Administration',
    'Pensions': 'General Government & Administration',
    'Debt Service': 'General Government & Administration',
    'Charter School Tuition': 'Education',
    'MBTA': 'Infrastructure & Public Works',
    'Other State Assessments': 'General Government & Administration',
    'Suffolk County Sheriff Dept': 'Public Safety',
    'Reserve': 'General Government & Administration',
    'Annual Audit Costs': 'General Government & Administration',
    'Housing Trust Fund': 'Community & Economic Development',
    'Reserve for Collective Bargaining City': 'General Government & Administration',
    'OPEB': 'General Government & Administration',
    'Risk Retention Reserve': 'General Government & Administration',
    'Tax Title': 'General Government & Administration'
}

# %%
philadelphia_spending['Category'] = philadelphia_spending['dept_name'].map(philly_mappings)
boston_capital['Category'] = boston_capital['Department'].map(boston_category_mapping)
boston_operating['Category'] = boston_operating['Dept'].map(boston_category_mapping)

# Aggregate the spending data for Philadelphia by the new 'Category' column
# Here, I'm summing up all the revised budget amounts for each year
philly_aggregated = philadelphia_spending.groupby('Category')[['2020 (Revised)', '2021 (Revised)', '2022 (Revised)', '2023 (Revised)', '2024 (Revised)', '2025 (Revised)']].sum()

# Similarly, aggregate the budget data for Boston. Assuming the columns in the capital and operating datasets are similarly named
boston_capital_aggregated = boston_capital.groupby('Category').sum()
boston_operating_aggregated = boston_operating.groupby('Category').sum()

# Strip leading/trailing spaces from column names in Boston datasets
boston_capital.columns = boston_capital.columns.str.strip()
boston_operating.columns = boston_operating.columns.str.strip()

# Convert relevant columns in the Boston datasets to numeric, handling non-numeric entries
columns_to_convert_capital = ['Authorization_Existing', 'Authorization_FY', 'Authorization_Future',
                              'Grant_Existing', 'Grant_FY', 'Grant_Future', 'GO_Expended',
                              'Capital_Year_0', 'CapitalYear_1', 'Capital_Year_25', 'Grant_Expended',
                              'Grant_Year_0', 'Grant_Year_1', 'GrantYear_25', 'External_Funds',
                              'Total_Project_Budget']

columns_to_convert_operating = ['FY21 Actual Expense', 'FY22 Actual Expense',
                                'FY23 Appropriation', 'FY24 Recommended']

for column in columns_to_convert_capital:
    boston_capital[column] = pd.to_numeric(boston_capital[column], errors='coerce')

for column in columns_to_convert_operating:
    boston_operating[column] = pd.to_numeric(boston_operating[column], errors='coerce')

# Aggregate the Boston data again
boston_capital_aggregated = boston_capital.groupby('Category').sum()
boston_operating_aggregated = boston_operating.groupby('Category').sum()

# Combine Boston's capital and operating budgets by category
boston_aggregated = boston_capital_aggregated.add(boston_operating_aggregated, fill_value=0)

# Aggregate the spending data for Philadelphia by the new 'Category' column
philly_aggregated = philadelphia_spending.groupby('Category').sum()  # Adjust the columns to sum as needed

# Now create a DataFrame for comparison
comparison = pd.DataFrame({
    'Philadelphia Total Spending': philly_aggregated.sum(axis=1),  # Adjust the columns to sum as needed
    'Boston Total Spending': boston_aggregated.sum(axis=1)  # Adjust the columns to sum as needed
})

# Sort the comparison for better readability, if desired
comparison.sort_values('Philadelphia Total Spending', ascending=False, inplace=True)

# Display the comparison
print(comparison)
# Out:
#                                      Philadelphia Total Spending  \
# Category
# General Government & Administration                 3.173805e+10
# Public Safety                                       1.815823e+10
# Infrastructure & Public Works                       6.026359e+09
# Health & Human Services                             4.979557e+09
# Education                                           1.929284e+09
# Culture & Recreation                                8.591194e+08
# Community & Economic Development                    5.290781e+08
# CInfrastructure & Public Works                               NaN
#
#                                      Boston Total Spending
# Category
# General Government & Administration           1.154874e+09
# Public Safety                                 3.521615e+09
# Infrastructure & Public Works                 7.045961e+09
# Health & Human Services                       2.406758e+09
# Education                                     8.358183e+09
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Updated data for the comparison DataFrame
comparison = pd.DataFrame({
    'Philadelphia Total Spending': {
        'General Government & Administration': 3.173805e+10,
        'Public Safety': 1.815823e+10,
        'Infrastructure & Public Works': 6.026359e+09,
        'Health & Human Services': 4.979557e+09,
        'Education': 1.929284e+09,
        'Culture & Recreation': 8.591194e+08,
        'Community & Economic Development': 5.290781e+08
    },
    'Boston Total Spending': {
        'General Government & Administration': 1.154874e+09,
        'Public Safety': 3.521615e+09,
        'Infrastructure & Public Works': 7.045961e+09,
        'Health & Human Services': 2.406758e+09,
        'Education': 8.358183e+09,
        'Culture & Recreation': 7.213087e+08,
        'Community & Economic Development': 9.078790e+08
    }
})

# Create the DataFrame from the dictionary
comparison_df = pd.DataFrame(comparison)

# Plotting the comparison
comparison_df.plot(kind='bar', figsize=(14, 8))

plt.title('Comparison of Spending by Category: Philadelphia vs. Boston')
plt.ylabel('Total Spending')
plt.xlabel('Category')
plt.yscale('log')  # Using a logarithmic scale due to large differences in values
plt.xticks(rotation=45, ha='right')  # Rotate the x-axis labels for better readability

# Show the plot
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py'>
